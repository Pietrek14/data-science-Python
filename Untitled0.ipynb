# %% [markdown]
# <a href="https://colab.research.google.com/github/Pietrek14/data-science-Python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("sexs2")
# Out:
# sexs2

# %%
print("aaaaaaaaaaaaaaaaaaaaaa")
